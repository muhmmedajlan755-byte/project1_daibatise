# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\USER\Desktop\5th sem\project1_daibatise\data\processed\mohammed_ajlan_p1w1_features.csv',parse_dates=["last_checkup_date"])

# %% [markdown]
# # classification and split

# %%
df.shape
# Out:
# (950, 21)

# %%
df['outcome'].value_counts(normalize=True)
# Out:
# outcome
# 0    0.712632
# 1    0.287368
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#   patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826   79    male            0    124.0            71.0
# 1     P00108   37    male            0    153.0            85.0
# 2     P00517   39  female            0    142.0            68.0
# 3     P00687   68  female            7    121.0            88.0
# 4     P00927   75  female            0    107.0            84.0
#
#    skin_thickness  insulin   bmi  diabetes_pedigree  ...  smoker  \
# 0            30.0    124.0  23.4              0.588  ...      NO
# 1            24.0     42.0  33.9              0.192  ...     YES
# 2            22.0    159.0  26.9              0.777  ...  UNKOWN
# 3            26.0    124.0  29.0              1.217  ...     YES
# 4            31.0    101.0  21.2              0.278  ...      NO
#
#   last_checkup_date outcome     age_band bmi_category glucose_band  \
# 0        2023-04-20       0       senior       normal  prediabetic
# ...

# %%
feautre_cols=['age','pregnancies','glucose','blood_pressure','skin_thickness','insulin',
              'bmi','diabetes_pedigree','bmi_category','glucose_band']
x=df[feautre_cols]
y=df['outcome']
x
# Out:
#      age  pregnancies     glucose  blood_pressure  skin_thickness  insulin  \
# 0     79            0  124.000000            71.0            30.0    124.0
# 1     37            0  153.000000            85.0            24.0     42.0
# 2     39            0  142.000000            68.0            22.0    159.0
# 3     68            7  121.000000            88.0            26.0    124.0
# 4     75            0  107.000000            84.0            31.0    101.0
# ..   ...          ...         ...             ...             ...      ...
# 945   64            2  117.855165            81.0            34.0    124.0
# 946   71            0  140.000000            64.0            37.0    124.0
# 947   40            0  130.000000            73.0            26.0    258.0
# 948   52            4  123.000000            76.0            22.0    189.0
# 949   42            0  114.000000            73.0            34.0    124.0
#
#       bmi  diabetes_pedigree bmi_category glucose_band
# ...

# %% [markdown]
# encode your banded feauters

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x.shape
# Out:
# (950, 13)

# %%
x
# Out:
#      age  pregnancies     glucose  blood_pressure  skin_thickness  insulin  \
# 0     79            0  124.000000            71.0            30.0    124.0
# 1     37            0  153.000000            85.0            24.0     42.0
# 2     39            0  142.000000            68.0            22.0    159.0
# 3     68            7  121.000000            88.0            26.0    124.0
# 4     75            0  107.000000            84.0            31.0    101.0
# ..   ...          ...         ...             ...             ...      ...
# 945   64            2  117.855165            81.0            34.0    124.0
# 946   71            0  140.000000            64.0            37.0    124.0
# 947   40            0  130.000000            73.0            26.0    258.0
# 948   52            4  123.000000            76.0            22.0    189.0
# 949   42            0  114.000000            73.0            34.0    124.0
#
# ...

# %%
x.columns
# Out:
# Index(['age', 'pregnancies', 'glucose', 'blood_pressure', 'skin_thickness',
#        'insulin', 'bmi', 'diabetes_pedigree', 'bmi_category_obese',
#        'bmi_category_overweight', 'bmi_category_underweight',
#        'glucose_band_normal', 'glucose_band_prediabetic'],
#       dtype='str')

# %% [markdown]
# split into tr

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\USER\Desktop\5th sem\project1_daibatise\my_env\Scripts\python.exe

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2, random_state=42, stratify=y
)

# %%
x_test.shape
# Out:
# (190, 13)

# %%
x_train.shape
# Out:
# (760, 13)

# %%
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# outcome
# 0    0.713158
# 1    0.286842
# Name: proportion, dtype: float64
# outcome
# 0    0.710526
# 1    0.289474
# Name: proportion, dtype: float64
